# %%
import json

# 네이버 쇼핑에서, android 라는 키워드로 검색한 상품 리스트 결과
data = """
{
    "lastBuildDate": "Thu, 06 May 2021 14:45:01 +0900",
    "total": 3999714,
    "start": 1,
    "display": 10,
    "items": [
        {
            "title": "아이린, 부모님과 골프 라운딩...짧은 치마에 드러난 '젓가락 각선미'",
            "originallink": "http://sports.chosun.com/news/ntype.htm?id=202105070100041460002498&servicedate=20210506",
            "link": "https://news.naver.com/main/read.nhn?mode=LSD&mid=sec&sid1=106&oid=076&aid=0003725638",
            "description": "아이린은 6일 자신의 인스타그램에 &quot;엄마 아빠랑 즐거운 <b>어린이</b>날&quot;이라는 글과 함께 사진을 게재했다. 공개된 사진 속 아이린은 <b>어린이</b>날을 맞이해 부모님과 골프 라운딩을 즐기고 있는 모습. 톱모델답게 늘씬한 각선미와... ",
            "pubDate": "Thu, 06 May 2021 14:43:00 +0900"
        },
        {
            "title": "투수로 1군 무대 밟은 나균안 “팬 함성에 아드레날린…다음에는 이기는 상황...",
            "originallink": "http://sports.khan.co.kr/news/sk_index.html?art_id=202105061442003&sec_id=510101&pt=nv",
            "link": "https://sports.news.naver.com/news.nhn?oid=144&aid=0000734942",
            "description": "지난 5일 부산 사직구장에서 열린 롯데와 KIA의 <b>어린이</b>날 맞대결에서 롯데는 0-5로 끌려가고 있었다. 패색이 짙어지면서 팬들의 침울함도 커졌다. 그러던 중 눈길을 끄는 선수의 등장이 있었다. 롯데는 선발 투수 댄... ",
            "pubDate": "Thu, 06 May 2021 14:43:00 +0900"
        },
        {
            "title": "장성군 서삼면 햇님달님봉사단, ‘오월 사랑나눔 행사’추진",
            "originallink": "https://daily.hankooki.com/lpage/society/202105/dh20210506144001148510.htm?s_ref=nv",
            "link": "https://daily.hankooki.com/lpage/society/202105/dh20210506144001148510.htm?s_ref=nv",
            "description": "어버이날과 <b>어린이</b>날 맞아 마스크, 장난감 등 후원 물품 전달 장성군 서삼면 햇님달님봉사단의 선행이... 기부된 물품들은 지난 4,5일 서삼면에 거주 중인 65세 이상 어르신 550여명과 <b>어린이</b> 30여명에게 전달됐다.... ",
            "pubDate": "Thu, 06 May 2021 14:42:00 +0900"
        },
        {
            "title": "전국서 터진 '잔인한 5월'의 신호…1년 전 대유행 재현되나",
            "originallink": "http://www.sisajournal.com/news/articleView.html?idxno=216633",
            "link": "https://news.naver.com/main/read.nhn?mode=LSD&mid=sec&sid1=102&oid=586&aid=0000024008",
            "description": "전날(676명)보다 100명 이상 감소한 것이지만, <b>어린이</b>날 휴일 검사 영향에 따른 것으로 확산세가 꺾인 것으로 보기는 어렵다. 오히려 <b>어린이</b>날 각종 유원지나 관광지에 많은 인파가 몰려들고 이동량이 증가한 것으로... ",
            "pubDate": "Thu, 06 May 2021 14:42:00 +0900"
        },
        {
            "title": "안성시, 함께 키우는 육아종합지원센터 개소",
            "originallink": "https://daily.hankooki.com/lpage/society/202105/dh20210506143953137880.htm?s_ref=nv",
            "link": "https://daily.hankooki.com/lpage/society/202105/dh20210506143953137880.htm?s_ref=nv",
            "description": "<b>어린이</b>집 관리와 지원·가정양육 맞춤형 지원 안성시는 6일 맞춤형 육아지원을 위한... 비대면 영상 개소식과 함께 진행된 이날 행사는 김보라 시장, 신원주 시의회의장, 영유아 및 부모대표, <b>어린이</b>집 관계자 등이... ",
            "pubDate": "Thu, 06 May 2021 14:42:00 +0900"
        },
        {
            "title": "직장 그만두는 엄마들...女 일자리 집어 삼킨 코로나19",
            "originallink": "https://www.hankyung.com/economy/article/202105064250i",
            "link": "https://news.naver.com/main/read.nhn?mode=LSD&mid=sec&sid1=101&oid=015&aid=0004542063",
            "description": "학교·<b>어린이</b>집이 문을 닫자 집에서 아이를 돌보기 위해 직장을 관두는 여성도 늘었다. 한국은행은 6일 이... 코로나19 확산을 막기 위한 방역 대책에 따라 학교, <b>어린이</b>집이 문을 닫으면서 육아 부담이 늘어난 것도... ",
            "pubDate": "Thu, 06 May 2021 14:42:00 +0900"
        },
        {
            "title": "‘컬투쇼’ 정동원 “중2병? 조금씩 오는 중…짜증 조금 늘었다”",
            "originallink": "http://mksports.co.kr/view/2021/437243/",
            "link": "https://news.naver.com/main/read.nhn?mode=LSD&mid=sec&sid1=106&oid=410&aid=0000783511",
            "description": "이어 “일단 옛날 같았으면 <b>어린이</b>날이면 뭐 가지고 싶다고 해야하는데 가지고 싶지 않고, 짜증도 조금 늘었다. 아침에 일찍 일어나면 막 그럴 때가 있더라”라고 고백했다.",
            "pubDate": "Thu, 06 May 2021 14:42:00 +0900"
        },
        {
            "title": "'고위험군' 60대 이상, 백신 예방효과도 높아…&quot;접종 당부&quot;",
            "originallink": "http://www.newsis.com/view/?id=NISX20210506_0001431980&cID=10201&pID=10200",
            "link": "https://news.naver.com/main/read.nhn?mode=LSD&mid=sec&sid1=102&oid=003&aid=0010484915",
            "description": "유치원·<b>어린이</b>집·초등학교(1·2학년) 교사·돌봄인력도 13일부터 사전예약을 받는다. 정부는 백신 도입이 계획대로 순조롭게 진행되고 있다고 강조했다. 이날까지 백신 456만회분이 도입됐고, 6월 말까지 1375회분이... ",
            "pubDate": "Thu, 06 May 2021 14:42:00 +0900"
        },
        {
            "title": "당진발전본부, 당진시 버스정류장 '스마트쉼터' 탈바꿈",
            "originallink": "http://www.ccnnews.co.kr/news/articleView.html?idxno=217992",
            "link": "http://www.ccnnews.co.kr/news/articleView.html?idxno=217992",
            "description": "스마트쉼터는 당진시 관내 가장 많은 버스노선이 경유하며, 주 이용객이 교통약자(<b>어린이</b>, 노약자 등)인 두 곳을 선별하여 설치되었으며, 당진버스터미널 및 당진1동 행정복지센터 인근에서 만나볼 수 있다. 해당 사업은... ",
            "pubDate": "Thu, 06 May 2021 14:42:00 +0900"
        },
        {
            "title": "아이작 과학전문학원, 해운대구 좌1동에 <b>어린이</b>날 맞아 도서 기탁",
            "originallink": "http://www.busan.com/view/busan/view.php?code=2021050614314132240",
            "link": "https://news.naver.com/main/read.nhn?mode=LSD&mid=sec&sid1=102&oid=082&aid=0001088757",
            "description": "해운대구 좌1동 행정복지센터(동장 천미경)는 5일 아이작 과학전문학원(대표 표미희)으로부터 <b>어린이</b>날을 맞아 한국사 학습만화책 등 초등학생용 도서88권(95만 원 상당)을 기탁 받았다고 밝혔다. 표미희 대표는“<b>어린이</b>... ",
            "pubDate": "Thu, 06 May 2021 14:42:00 +0900"
        }
    ]
}
"""

json_data = json.loads(data)
print(json_data['items'][0]['title'])
print(json_data['items'][0]['link'])
print(json_data['items'][0]['description'])
# Out:
# 아이린, 부모님과 골프 라운딩...짧은 치마에 드러난 '젓가락 각선미'
# https://news.naver.com/main/read.nhn?mode=LSD&mid=sec&sid1=106&oid=076&aid=0003725638
# 아이린은 6일 자신의 인스타그램에 &quot;엄마 아빠랑 즐거운 <b>어린이</b>날&quot;이라는 글과 함께 사진을 게재했다. 공개된 사진 속 아이린은 <b>어린이</b>날을 맞이해 부모님과 골프 라운딩을 즐기고 있는 모습. 톱모델답게 늘씬한 각선미와...

# %% [markdown]
# ### 네이버 OPEN API로 크롤링하기

# %%
import requests
import pprint

client_id='m22pVg8bEogJW3D83eHA'
client_secret='NEvoVTfvRf'

naver_open_api = 'https://openapi.naver.com/v1/search/news.json?query=애플'
header_params={"X-Naver-Client-Id":client_id, "X-Naver-Client-Secret":client_secret}
res = requests.get(naver_open_api, headers=header_params)
    
if res.status_code == 200:
    data = res.json()
    for index, item in enumerate(data['items']):
        print(index + 1, item['title'], item['link'])
else:
    print("Error Code:", res.status_code)
# Out:
# 1 삼성 ‘갤럭시Z폴드3’, 희망 사항? 실제 유출? 관심집중 https://news.naver.com/main/read.nhn?mode=LSD&mid=sec&sid1=105&oid=018&aid=0004922093
# 2 '퓨어 섹시' 온리원오브, '인스팅트 파트.1' 활동 마무리 https://news.naver.com/main/read.nhn?mode=LSD&mid=sec&sid1=106&oid=018&aid=0004922087
# 3 핸디커뮤니케이션즈, 모바일 게임 '로드오브워' 정식 출시 http://gamefocus.co.kr/detail.php?number=117140
# 4 온리원오브, 존재감 각인…응답 받은 실험 정신 https://news.naver.com/main/read.nhn?mode=LSD&mid=sec&sid1=106&oid=382&aid=0000908063
# 5 구글 '인앱 결제 강제화' 논란 지속...&quot;시장 지배력 이용한 끼워팔기&quot; http://www.todaykorea.co.kr/news/articleView.html?idxno=287186
# 6 가이아모바일, 하반기 출시 예정 '요철세계' 사전예약 실시 http://gamefocus.co.kr/detail.php?number=117137
# 7 푸조, 전기차 야간 시승행사 ‘라이언 나이트’ 참가자 모집 https://bizn.donga.com/car/3/all/20210506/106793782/1
# 8 엡손, 100% 재생에너지 전환 RE 100 가입, ESG 경영 가속화 http://www.technoa.co.kr/news/articleView.html?idxno=92106
# 9 &quot;반도체 때문에...<b>애플</b>, 올인원 PC 시장서 HP 제치고 1위&quot; https://news.naver.com/main/read.nhn?mode=LSD&mid=sec&sid1=104&oid=030&aid=0002943192
# ...

# %%
import requests
import openpyxl

client_id='m22pVg8bEogJW3D83eHA'
client_secret='NEvoVTfvRf'
start, num = 1,0

excel_file = openpyxl.Workbook()
excel_sheet = excel_file.active
excel_sheet.column_dimensions['B'].width = 100
excel_sheet.column_dimensions['C'].width = 100
excel_sheet.append(['랭킹', '제목', '링크'])

for index in range(10):
    start_number = start + (index * 100)
    naver_open_api = 'https://openapi.naver.com/v1/search/news.json?query=애플' + str(start_number)
    header_params = {'X-Naver-Client-Id':client_id,'X-Naver-Client-Secret':client_secret}
    res = requests.get(naver_open_api, headers=header_params)
    if res.status_code == 200:
        data = res.json()
        for item in data['items']:
            num += 1
            excel_sheet.append([num, item['title'], item['link']])
    else:
        print("Error Code:", res.status_code)
        
excel_file.save('IT.xlsx')
excel_file.close()

# %% [markdown]
# ### 공공데이터 OPEN API 사용

# %%
import requests

service_key = 'wspk%2FIWNQzAt%2BM9l%2BblbbAYDv67bleOZEl08PHzCiLjeVznbM%2BWb4IO5C5m8Fo71jEZdIeoLW4g5BO7X6XkcFQ%3D%3D'
params = '&numOfRows=10&pageNo=1&sidoName=부산'
open_api='http://apis.data.go.kr/B552584/ArpltnInforInqireSvc/getCtprvnRltmMesureDnsty?ServiceKey='+ service_key + params
res = requests.get(open_api)
print(res.text)
# Out:
# <?xml version="1.0" encoding="UTF-8"?>
# <response>
#   <header>
#     <resultCode>00</resultCode>
#     <resultMsg>NORMAL_CODE</resultMsg>
#   </header>
#   <body>
#     <items>
#       <item>
#         <so2Grade>1</so2Grade>
#         <coFlag/>
#         <khaiValue>77</khaiValue>
#         <so2Value>0.002</so2Value>
#         <coValue>0.2</coValue>
#         <pm10Flag/>
#         <o3Grade>2</o3Grade>
#         <pm10Value>67</pm10Value>
#         <khaiGrade>2</khaiGrade>
#         <sidoName>부산</sidoName>
#         <no2Flag/>
#         <no2Grade>1</no2Grade>
#         <o3Flag/>
#         <so2Flag/>
#         <dataTime>2021-05-06 16:00</dataTime>
#         <coGrade>1</coGrade>
#         <no2Value>0.018</no2Value>
#         <stationName>광복동</stationName>
#         <pm10Grade>2</pm10Grade>
#         <o3Value>0.043</o3Value>
#       </item>
#       <item>
#         <so2Grade/>
#         <coFlag>점검및교정</coFlag>
#         <khaiValue>-</khaiValue>
#         <so2Value>-</so2Value>
# ...

# %%
import requests
from bs4 import BeautifulSoup

service_key = 'wspk%2FIWNQzAt%2BM9l%2BblbbAYDv67bleOZEl08PHzCiLjeVznbM%2BWb4IO5C5m8Fo71jEZdIeoLW4g5BO7X6XkcFQ%3D%3D'
params = '&numOfRows=10&pageNo=1&sidoName=서울'
open_api='http://apis.data.go.kr/B552584/ArpltnInforInqireSvc/getCtprvnRltmMesureDnsty?ServiceKey='+ service_key + params
res = requests.get(open_api)
soup = BeautifulSoup(res.content, 'html.parser')

data = soup.find_all('item')
for item in data:
    stationname=item.find('stationname')
    pm10grade = item.find('pm10grade')
    print(stationname.get_text(), pm10grade.get_text())
# Out:
# 중구 2
# 한강대로 2
# 종로구 2
# 청계천로 2
# 종로 2
# 용산구 2
# 광진구 2
# 성동구 2
# 강변북로 2
# 중랑구 2

# %%
import requests
open_api = 'http://apis.data.go.kr/B552584/ArpltnInforInqireSvc/getCtprvnRltmMesureDnsty'
serviceKey = '?serviceKey=wspk%2FIWNQzAt%2BM9l%2BblbbAYDv67bleOZEl08PHzCiLjeVznbM%2BWb4IO5C5m8Fo71jEZdIeoLW4g5BO7X6XkcFQ%3D%3D'
returnType = '&returnType=json'
numOfRows = '&numOfRows=100'
sidoName = '&sidoName=서울'
res = requests.get(open_api+serviceKey+returnType+numOfRows+sidoName)
#print(res.text)
if res.status_code == 200:
    data = res.json()
    print(data['response']['body']['items'])
    # for index, item in enumerate(data['items']):
    #     print (index, item)
else:
    print("Error Code:", res.status_code)
# Out:
# [{'so2Grade': '1', 'coFlag': None, 'khaiValue': '94', 'so2Value': '0.004', 'coValue': '0.5', 'pm10Flag': None, 'o3Grade': '2', 'pm10Value': '97', 'khaiGrade': '2', 'sidoName': '서울', 'no2Flag': None, 'no2Grade': '1', 'o3Flag': None, 'so2Flag': None, 'dataTime': '2021-05-06 16:00', 'coGrade': '1', 'no2Value': '0.021', 'stationName': '중구', 'pm10Grade': '2', 'o3Value': '0.073'}, {'so2Grade': '1', 'coFlag': None, 'khaiValue': '99', 'so2Value': '0.003', 'coValue': '0.8', 'pm10Flag': None, 'o3Grade': '2', 'pm10Value': '110', 'khaiGrade': '2', 'sidoName': '서울', 'no2Flag': None, 'no2Grade': '2', 'o3Flag': None, 'so2Flag': None, 'dataTime': '2021-05-06 16:00', 'coGrade': '1', 'no2Value': '0.033', 'stationName': '한강대로', 'pm10Grade': '2', 'o3Value': '0.036'}, {'so2Grade': '1', 'coFlag': None, 'khaiValue': '95', 'so2Value': '0.005', 'coValue': '0.5', 'pm10Flag': None, 'o3Grade': '2', 'pm10Value': '96', 'khaiGrade': '2', 'sidoName': '서울', 'no2Flag': None, 'no2Grade': '1', 'o3Flag': None, 'so2Flag'
# ...
